# %%
import numpy as np
import pandas as pd
import os
from glob import glob
import itertools
import fnmatch
import random
import matplotlib.pylab as plt
import seaborn as sns
import cv2
from PIL import Image
from ann_visualizer.visualize import ann_viz;

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
import keras
from keras import backend as K
from keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
from keras.models import Sequential, load_model
from keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization, Conv2D, MaxPooling2D
# %matplotlib inline
from tensorflow.keras.utils import plot_model

# %%
imagePatches = glob('/Users/abhivyaktisatti/Desktop/ML/archive/*/*/*.png', recursive=True)
for filename in imagePatches[0:10]:
    print(filename)
# Out:
# /Users/abhivyaktisatti/Desktop/ML/archive/9036/0/9036_idx5_x1051_y2401_class0.png
# /Users/abhivyaktisatti/Desktop/ML/archive/9036/0/9036_idx5_x2951_y951_class0.png
# /Users/abhivyaktisatti/Desktop/ML/archive/9036/0/9036_idx5_x3001_y1451_class0.png
# /Users/abhivyaktisatti/Desktop/ML/archive/9036/0/9036_idx5_x3051_y801_class0.png
# /Users/abhivyaktisatti/Desktop/ML/archive/9036/0/9036_idx5_x951_y1901_class0.png
# /Users/abhivyaktisatti/Desktop/ML/archive/9036/0/9036_idx5_x2251_y751_class0.png
# /Users/abhivyaktisatti/Desktop/ML/archive/9036/0/9036_idx5_x1901_y401_class0.png
# /Users/abhivyaktisatti/Desktop/ML/archive/9036/0/9036_idx5_x3201_y1101_class0.png
# /Users/abhivyaktisatti/Desktop/ML/archive/9036/0/9036_idx5_x3351_y1251_class0.png
# /Users/abhivyaktisatti/Desktop/ML/archive/9036/0/9036_idx5_x2051_y2551_class0.png

# %%
image_sample = "/Users/abhivyaktisatti/Desktop/ML/archive/9036/0/9036_idx5_x1051_y2401_class0.png"
dsize=(50,50)

image = cv2.imread(image_sample)
image = cv2.resize(image, dsize)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB)); plt.axis('off')
# Out:
# (-0.5, 49.5, 49.5, -0.5)

# %%
resized_images,labels_arr = [],[]
dsize=(50,50)
    
for img in imagePatches[0:20000]:
    full_size_image = cv2.imread(img)
    resized_images.append(cv2.resize(full_size_image, dsize, interpolation=cv2.INTER_CUBIC))
    labels_arr.append(int(img[-5]))

# %%
def describeData(a,b):
    print('Total number of images: {}'.format(len(a)))
    print('Number of IDC(-) Images: {}'.format(len(a)-np.sum(b)))
    print('Number of IDC(+) Images: {}'.format(np.sum(b)))
    print('Image shape (Width, Height, Channels): {}'.format(a[0].shape))
describeData(resized_images,labels_arr)
# Out:
# Total number of images: 20000
# Number of IDC(-) Images: 16051
# Number of IDC(+) Images: 3949
# Image shape (Width, Height, Channels): (50, 50, 3)

# %%
X=np.array(resized_images)
Y=pd.Series(labels_arr) 
X=X/255.0
 
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, )

print("Training Data Shape:", X_train.shape)
print("Testing Data Shape:", X_test.shape)
# Out:
# Training Data Shape: (14000, 50, 50, 3)
# Testing Data Shape: (6000, 50, 50, 3)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Example: Assuming Y is a list or NumPy array of class labels
classes, counts = np.unique(Y, return_counts=True)  # Get unique classes and their counts

plt.bar(classes, counts, color='skyblue')  # Create a bar plot
plt.xlabel('Class Labels')  # Label for x-axis
plt.ylabel('Frequency')     # Label for y-axis
plt.title('Distribution of Target Classes')  # Title of the plot
plt.xticks(classes)         # Ensure all class labels are shown on x-axis
plt.show()                  # Display the plot

# %%
image_shape = 50*50*3

X_train = X_train.reshape(X_train.shape[0], image_shape)
X_test = X_test.reshape(X_test.shape[0], image_shape)

# %%
print("Shape of flattened training data:",X_train.shape,"\nShape of flatened testing data: ",X_test.shape)
# Out:
# Shape of flattened training data: (14000, 7500)
# Shape of flatened testing data:  (6000, 7500)

# %%
from imblearn.under_sampling import RandomUnderSampler
#from sklearn.utils.validation import _check_feature_names


# Ros = RandomOverSampler(sampling_strategy='auto') 
Rus = RandomUnderSampler(sampling_strategy='auto')

X_trainRusFlat, Y_trainRus = Rus.fit_resample(X_train, Y_train)
X_testRusFlat, Y_testRus = Rus.fit_resample(X_test, Y_test)

#Reshape the images
X_trainRus = X_trainRusFlat.reshape(len(X_trainRusFlat),50,50,3)
X_testRus = X_testRusFlat.reshape(len(X_testRusFlat),50,50,3)

# Encode labels
Y_trainRus = to_categorical(Y_trainRus, num_classes = 2)
Y_testRus = to_categorical(Y_testRus, num_classes = 2)

# %%
print("New shape of Train data =",X_trainRus.shape)
print("New shape of Test data =",X_testRus.shape)
# Out:
# New shape of Train data = (5500, 50, 50, 3)
# New shape of Test data = (2398, 50, 50, 3)

# %%
class MetricsCheckpoint(Callback):
    """Callback that saves metrics after each epoch"""
    def __init__(self, savepath):
        super(MetricsCheckpoint, self).__init__()
        self.savepath = savepath
        self.history = {}
    def on_epoch_end(self, epoch, logs=None):
        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)
        np.save(self.savepath, self.history)

# %%
def plotLearningCurve():
    
    plt.figure(figsize=(10,6))
    metrics = np.load('logs.npy', allow_pickle=True)[()]
    filt = ['acc'] # try to add 'loss' to see the loss learning curve
    for k in filter(lambda x : np.any([kk in x for kk in filt]), metrics.keys()):
        l = np.array(metrics[k])
        plt.plot(l, c= 'r' if 'val' not in k else 'b', label='val' if 'val' in k else 'train')
        x = np.argmin(l) if 'loss' in k else np.argmax(l)
        y = l[x]
        plt.scatter(x,y, lw=0, alpha=0.25, s=100, c='r' if 'val' not in k else 'b')
        plt.text(x, y, '{} = {:.4f}'.format(x,y), size='15', color= 'r' if 'val' not in k else 'b')
    
    plt.legend(loc=4)
    plt.axis([0, None, None, None]);
    plt.grid()
    plt.xlabel('Number of epochs')

# %%
def plot_learning_curve(history):
    plt.figure(figsize=(10, 6))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper left')

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper left')
    plt.show()

# %%
def plot_confusion_matrix(cm, normalize=False, cmap=plt.cm.Blues):
    classes = {0: 'IDC(-)', 1: 'IDC(+)'}
    plt.figure(figsize=(6, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title('Confusion Matrix')
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j], horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense

def build_base_CNN(num_classes=2, input_shape=(50, 50, 3)):
    model = Sequential()
    model.add(Conv2D(32, (5, 5), activation='relu', input_shape=input_shape))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.2))
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(num_classes, activation='softmax'))
    return model

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense

def build_final_CNN(num_classes=2, input_shape=(50, 50, 3)):
    model = Sequential()
    
    # Add convolutional and pooling layers
    model.add(Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.2))
    
    # Flatten the output of the convolutional layers
    model.add(Flatten())
    
    # Add a fully connected layer
    model.add(Dense(64, activation='relu'))
    
    # Add the output layer with 2 units for binary classification
    model.add(Dense(num_classes, activation='softmax'))  # Use softmax for multi-class classification
    
    return model

# %%
def build_base_CNN(num_classes=2, input_shape=(50, 50, 3)):
    model = Sequential()
    model.add(Conv2D(32, (5, 5), activation='relu', input_shape=input_shape))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.2))
    model.add(Conv2D(32, (5, 5), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.2))
    model.add(Flatten())
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.4))
    model.add(Dense(num_classes, activation='sigmoid'))
    return model

# %%
def build_final_CNN(num_classes=2, input_shape=(50, 50, 3)):
    model = Sequential()
    model.add(Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(MaxPooling2D(pool_size=(3, 3)))
    model.add(Dropout(0.2))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(3, 3)))
    model.add(Dropout(0.3))
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(num_classes, activation='sigmoid'))
    return model

# %%
def eval_model(model, a, b, c, d, model_name=None):
    batch_size = 32
    epochs = 25
    model.compile(loss="binary_crossentropy", optimizer="adam", metrics=['accuracy'])
    history = model.fit(a, b, batch_size=batch_size, epochs=epochs, verbose=1, validation_data=(c, d))
    score = model.evaluate(c, d, verbose=0)
    print('\nAccuracy:', score[1])
    y_pred = model.predict(c)
    print('\n', classification_report(np.where(d > 0)[1], np.argmax(y_pred, axis=1)))
    plot_learning_curve(history)
    confusion_mtx = confusion_matrix(np.argmax(d, axis=1), np.argmax(y_pred, axis=1))
    plot_confusion_matrix(confusion_mtx)

# %%
eval_model(build_base_CNN(), X_trainRus, Y_trainRus, X_testRus, Y_testRus, 'base_CNN')
# Out:
# /Users/abhivyaktisatti/Library/Python/3.9/lib/python/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/25
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 35s 176ms/step - accuracy: 0.5128 - loss: 0.6956 - val_accuracy: 0.5955 - val_loss: 0.6859
# Epoch 2/25
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 30s 174ms/step - accuracy: 0.6416 - loss: 0.6296 - val_accuracy: 0.6580 - val_loss: 0.6038
# Epoch 3/25
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 31s 181ms/step - accuracy: 0.7472 - loss: 0.5213 - val_accuracy: 0.8115 - val_loss: 0.4634
# Epoch 4/25
# 172/172 ━━━━━━━━━━━━━━━━━━━━
Library/Python/3.9/lib/python/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/25
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 17s 79ms/step - accuracy: 0.5478 - loss: 0.6925 - val_accuracy: 0.7807 - val_loss: 0.5161
# Epoch 2/25
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 14s 83ms/step - accuracy: 0.7721 - loss: 0.5002 - val_accuracy: 0.7832 - val_loss: 0.4795
# Epoch 3/25
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 13s 76ms/step - accuracy: 0.8103 - loss: 0.4467 - val_accuracy: 0.8240 - val_loss: 0.4304
# Epoch 4/25
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 13s 74ms/step - accuracy: 0.8252 - loss: 0.4129 - val_accuracy: 0.8290 - val_loss: 0.4150
# Epoch 5/25
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 13s 74ms/step - accuracy: 0.8288 - loss: 0.4074 - val_accuracy: 0.8386 - val_loss: 0.4041
# Epoch 6/25
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 13s 74ms/step - accuracy: 0.8098 - loss: 0.4410 - val_accuracy: 0.8257 - val_loss: 0.4156
# Epoch 7/25
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 13s 74ms/step - accuracy: 0.8370 - loss: 0.3938 - val_accuracy: 0.8015 - val_loss: 0.4574
# Epoch 8/25
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 13s 73ms/step - accuracy: 0.8318 - loss: 0.4060 - val_accuracy: 0.8290 - val_loss: 0.4125
# Epoch 9/25
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 12s 72ms/step - accuracy: 0.8247 - loss: 0.4185 - val_accuracy: 0.8344 - val_loss: 0.4087
# Epoch 10/25
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 13s 73ms/step - accuracy: 0.8365 - loss: 0.3947 - val_accuracy: 0.8282 - val_loss: 0.4043
# Epoch 11/25
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 15s 86ms/step - accuracy: 0.8450 - loss: 0.3724 - val_accuracy: 0.8190 - val_loss: 0.4129
# Epoch 12/25
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 13s 76ms/step - accuracy: 0.8464 - loss: 0.3750 - val_accuracy: 0.8315 - val_loss: 0.3964
# Epoch 13/25
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 14s 80ms/step - accuracy: 0.8356 - loss: 0.3787 - val_accuracy: 0.8324 - val_loss: 0.3875
# Epoch 14/25
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 13s 75ms/step - accuracy: 0.8452 - loss: 0.3762 - val_accuracy: 0.8490 - val_loss: 0.3707
# Epoch 15/25
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 14s 81ms/step - accuracy: 0.8501 - loss: 0.3734 - val_accuracy: 0.7977 - val_loss: 0.4566
# Epoch 16/25
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 17s 100ms/step - accuracy: 0.8497 - loss: 0.3655 - val_accuracy: 0.8432 - val_loss: 0.3739
# Epoch 17/25
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 13s 76ms/step - accuracy: 0.8448 - loss: 0.3633 - val_accuracy: 0.8424 - val_loss: 0.3792
# Epoch 18/25
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 13s 74ms/step - accuracy: 0.8547 - loss: 0.3469 - val_accuracy: 0.8374 - val_loss: 0.3849
# Epoch 19/25
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 14s 79ms/step - accuracy: 0.8589 - loss: 0.3336 - val_accuracy: 0.8357 - val_loss: 0.3979
# Epoch 20/25
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 14s 80ms/step - accuracy: 0.8545 - loss: 0.3468 - val_accuracy: 0.8465 - val_loss: 0.3679
# Epoch 21/25
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 15s 88ms/step - accuracy: 0.8552 - loss: 0.3457 - val_accuracy: 0.8303 - val_loss: 0.3861
# Epoch 22/25
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 15s 89ms/step - accuracy: 0.8632 - loss: 0.3483 - val_accuracy: 0.8532 - val_loss: 0.3511
# Epoch 23/25
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 15s 84ms/step - accuracy: 0.8482 - loss: 0.3476 - val_accuracy: 0.8219 - val_loss: 0.4037
# Epoch 24/25
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 15s 85ms/step - accuracy: 0.8757 - loss: 0.3193 - val_accuracy: 0.8474 - val_loss: 0.3499
# Epoch 25/25
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 16s 95ms/step - accuracy: 0.8603 - loss: 0.3251 - val_accuracy: 0.7777 - val_loss: 0.5123
#
# Accuracy: 0.7777314186096191
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step
#
#                precision    recall  f1-score   support
#
#            0       0.91      0.61      0.73      1199
#            1       0.71      0.94      0.81      1199
#
#     accuracy                           0.78      2398
#    macro avg       0.81      0.78      0.77      2398
# weighted avg       0.81      0.78      0.77      2398

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D

# Define the model
model = Sequential()

# Add layers to the model (example architecture)
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(64, 64, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))  # Adjust the number of output units as per your problem

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Save the model
model.save("breastcancer2.keras")
# Out:
# /Users/abhivyaktisatti/Library/Python/3.9/lib/python/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.save("breastcancer2.keras")
